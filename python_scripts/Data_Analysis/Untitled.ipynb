# %%
from PIL import Image
from pytesseract import pytesseract
  
# Defining paths to tesseract.exe
# and the image we would be using
path_to_tesseract = r"C:\Program Files\Tesseract-OCR\tesseract.exe"
image_path = r"Res_Pic_v3.jpeg"
  
# Opening the image & storing it in an image object
img = Image.open(image_path)
  
# Providing the tesseract executable
# location to pytesseract library
pytesseract.tesseract_cmd = path_to_tesseract
  
config = ("--psm 12")
# Passing the image object to image_to_string() function
# This function will extract the text from the image
text = pytesseract.image_to_string(img,lang='eng',config = config)
  
# Displaying the extracted text
print(text[:-1])
# Out:
# 06.461 78:0 |

# %%
image_path = r"Res_Pic.jpeg"
img2 = Image.open(image_path)
img2.size
# Out:
# (901, 1600)

# %%
img3 = img2.crop((200,590,500,650))
img3
# Out:
# <PIL.Image.Image image mode=RGB size=300x60>

# %%
pytesseract.tesseract_cmd = path_to_tesseract
  
config = ("--psm 12")
# Passing the image object to image_to_string() function
# This function will extract the text from the image
text = pytesseract.image_to_string(img3,lang='eng',config = config)
  
# Displaying the extracted text
print(text[:-1])
# Out:
# 06.461 7810 |

# %%
import os
fnames = os.listdir("./Res_Images/")
fnames
# Out:
# ['20230325_182655.jpg',
#  '20230325_182808.jpg',
#  '20230325_182936.jpg',
#  '20230325_183202.jpg',
#  '20230325_183252.jpg',
#  '20230325_183432.jpg',
#  '20230325_183525.jpg',
#  '20230325_183659.jpg',
#  '20230325_183803.jpg',
#  '20230325_183930.jpg',
#  '20230325_184005.jpg',
#  '20230325_184122.jpg',
#  '20230325_184326.jpg',
#  '20230325_184411.jpg',
#  '20230325_184526.jpg',
#  '20230325_184723.jpg',
#  '20230325_184821.jpg',
#  '20230325_184917.jpg',
#  '20230325_185030.jpg',
#  '20230325_185142.jpg',
#  '20230325_185243.jpg',
#  '20230325_185342.jpg',
#  '20230325_185457.jpg',
#  '20230325_185548.jpg',
#  '20230325_185652.jpg',
#  '20230325_185836.jpg',
#  '20230325_185933.jpg',
#  '20230325_190020.jpg',
#  '20230325_190108.jpg',
#  '20230325_190145.jpg',
#  '20230325_190247.jpg',
#  '20230325_190349.jpg',
#  '20230325_190459.jpg',
#  '20230325_190556.jpg',
#  '20230325_190724.jpg',
#  '20230325_190805.jpg',
#  '20230325_190903.jpg',
#  '20230325_190936.jpg',
# ...

# %%
f2 = r"Res_Images/20230325_184122.jpg"
img = Image.open(f2)
print(img.size)
img3 = img.crop((1650,940,1850,1600))
# img2 = img3.transpose(Image.ROTATE_180)
# img2 = img2.transpose(Image.ROTATE_90)
# Providing the tesseract executable
# location to pytesseract library
pytesseract.tesseract_cmd = path_to_tesseract

config = ("--psm 11")
# Passing the image object to image_to_string() function
# This function will extract the text from the image
text = pytesseract.image_to_string(img2,lang='eng',config = config)

# Displaying the extracted text
print(text[:-1])
# Out:
# (4624, 2604)
# C:\Users\gonah\AppData\Local\Temp\ipykernel_30516\2495352651.py:5: DeprecationWarning: ROTATE_180 is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.ROTATE_180 instead.
#   img2 = img3.transpose(Image.ROTATE_180)
# C:\Users\gonah\AppData\Local\Temp\ipykernel_30516\2495352651.py:6: DeprecationWarning: ROTATE_90 is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.ROTATE_90 instead.
#   img2 = img2.transpose(Image.ROTATE_90)
# tsa)
#
# = = &

# %%
img3
# Out:
# <PIL.Image.Image image mode=RGB size=200x660>

# %%
for f in fnames:
    f2 = r"Res_Images/" + f
    img = Image.open(f2)
    img1 = img.crop((1300,1300,1500,1900))
    img2 = img1.transpose(Image.ROTATE_180)
    img2 = img2.transpose(Image.ROTATE_90)
    text = pytesseract.image_to_string(img2,lang='eng',config = config)
#     print(text[:-1])
#     print(len(text))
    if len(text) != 0 and len(text) < 15:
        print(text[:-1])
# Out:
# C:\Users\gonah\AppData\Local\Temp\ipykernel_11656\805111515.py:5: DeprecationWarning: ROTATE_180 is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.ROTATE_180 instead.
#   img2 = img1.transpose(Image.ROTATE_180)
# C:\Users\gonah\AppData\Local\Temp\ipykernel_11656\805111515.py:6: DeprecationWarning: ROTATE_90 is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.ROTATE_90 instead.
#   img2 = img2.transpose(Image.ROTATE_90)
# ae
# 06.168 39:0
# 205.723 444
# 05.453 80 c
# 05.364 25 ic
# 05.349 52k
# 05.307 5510
# 05.177 5510
# 03.633 97:0
# 03.628 06
# 03.588 62:0
# 03.463 72a
# 03.461 99k
# 3.311 87 10
# .
#
# ia)
#
# INA
# =
#
# & ga
#
# y=

# %%
f2 = r"Res_Images/Rotated_20230325_184122.jpg"
img = Image.open(f2)
print(img.size)
# Out:
# (4624, 2604)

# %%
img1 = img.crop((3150,690,3300,1300))
img1
text = pytesseract.image_to_string(img1,lang='eng',config = config)
print(text[:-1])
# Out:
# 06.168 394.

# %%
f2 = r"Res_Images/20230325_184122.jpg"
img = Image.open(f2)
print(img.size)
img1 = img.crop((1300,1300,1500,1900))
img1
img2 = img1.transpose(Image.ROTATE_180)
img2 = img2.transpose(Image.ROTATE_90)
text = pytesseract.image_to_string(img2,lang='eng',config = config)
print(text[:-1])
# Out:
# (4624, 2604)
# C:\Users\gonah\AppData\Local\Temp\ipykernel_11656\3801600321.py:6: DeprecationWarning: ROTATE_180 is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.ROTATE_180 instead.
#   img2 = img1.transpose(Image.ROTATE_180)
# C:\Users\gonah\AppData\Local\Temp\ipykernel_11656\3801600321.py:7: DeprecationWarning: ROTATE_90 is deprecated and will be removed in Pillow 10 (2023-07-01). Use Transpose.ROTATE_90 instead.
#   img2 = img2.transpose(Image.ROTATE_90)
# 06.168 39:0
